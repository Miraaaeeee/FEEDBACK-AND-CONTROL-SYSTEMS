# %%
# !pip install pyserial
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyserial in c:\users\mira\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (3.5)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\Mira\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import serial
import time

# --- CONFIGURATION ---
ARDUINO_PORT = 'COM7'
BAUD_RATE = 9600

def main():
    try:
        ser = serial.Serial(ARDUINO_PORT, BAUD_RATE, timeout=1)
        print(f"Connected to Arduino on {ARDUINO_PORT}")
        
        # Wait for reboot
        time.sleep(2)

        while True:
            user_input = input("\nEnter degree (0-180) or 'exit': ")
            
            if user_input.lower() == 'exit':
                break

            command = user_input + '\n'
            ser.write(command.encode('utf-8'))
            
            time.sleep(0.1)

            if ser.in_waiting > 0:
                response = ser.readline().decode('utf-8').strip()
                print(f"Arduino: {response}")

    except serial.SerialException as e:
        print(f"Error: {e}")
    finally:
        if 'ser' in locals() and ser.is_open:
            ser.close()

if __name__ == '__main__':
    main()
# Out:
# Connected to Arduino on COM7
